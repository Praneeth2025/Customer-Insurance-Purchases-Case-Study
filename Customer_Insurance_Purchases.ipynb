# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Social_Network_Ads.csv")
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
data.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
#adding split and feature scaling

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = data.iloc[:, :-1] 
Y = data["Purchased"]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1)

# %%
#standard scaling

standard=StandardScaler()
x_train=standard.fit_transform(x_train)
x_test=standard.transform(x_test)
x_train
# Out:
# array([[ 0.31595897, -0.55498165],
#        [ 0.99243866, -1.07655977],
#        [-0.94036046,  0.48817458],
#        [-0.94036046, -0.4390754 ],
#        [-0.07060086, -1.07655977],
#        [-0.26388077,  0.05352615],
#        [ 2.05547818,  0.1694324 ],
#        [-1.61684016, -0.0623801 ],
#        [ 0.89579871, -0.55498165],
#        [-0.84372051,  0.14045584],
#        [-0.16724081, -0.58395821],
#        [-1.32692029, -0.4390754 ],
#        [ 2.15211814, -1.04758321],
#        [ 0.41259892,  0.57510426],
#        [-0.26388077, -0.58395821],
#        [-0.84372051, -1.22144258],
#        [ 1.95883823,  0.89384645],
#        [ 1.86219827, -1.07655977],
#        [ 0.50923888,  1.82109643],
#        [ 0.31595897,  0.05352615],
#        [ 0.50923888,  1.21258863],
#        [-0.55380064, -1.5112082 ],
#        [ 0.89579871, -0.78679415],
#        [-1.03700042, -0.46805197],
#        [-1.32692029, -1.25041914],
#        [-1.71348012, -0.61293478],
#        [-1.90676003, -0.75781759],
# ...

# %%
#Graphical Representation
plt.scatter(x_train[:,0], x_train[:,-1], c=y_train)
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Social Network Ads - Training Set')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
logistic.fit(x_train,y_train)
from sklearn.metrics import accuracy_score
y_pred = logistic.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
precision=precision_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(accuracy)
print(precision)
print(f1score)
# Out:
# 0.825
# 0.7
# 0.6666666666666666

# %% [markdown]
# K Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
y_pred = KNN.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
precision=precision_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(accuracy)
print(precision)
print(f1score)
# Out:
# 0.925
# 0.7857142857142857
# 0.88

# %% [markdown]
# support vector machine

# %%
from sklearn.svm import SVC
support_vector_classifier=SVC()
support_vector_classifier.fit(x_train,y_train)
y_pred = KNN.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
precision=precision_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(accuracy)
print(precision)
print(f1score)
# Out:
# 0.925
# 0.7857142857142857
# 0.88

# %% [markdown]
# Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(random_state=20)
dt_model.fit(x_train, y_train)
y_pred=dt_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
precision=precision_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(accuracy)
print(precision)
print(f1score)
# Out:
# 0.875
# 0.7142857142857143
# 0.8

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)
y_pred=rf_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
precision=precision_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(accuracy)
print(precision)
print(f1score)
# Out:
# 0.9
# 0.7692307692307693
# 0.8333333333333333

# %% [markdown]
# QUESTION 1

# %%
predictions=np.array([[30,6700],[40,0],[40,100000],[50,0]])
predictions=standard.transform(predictions)
# Out:
# c:\Users\vamsi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#GRAPHS
plt.scatter(x_train[:,0], x_train[:,-1], c=y_train)
plt.scatter(predictions[:,0],predictions[:,1],color="red")#in the graph the predicted points are marked with red color
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Social Network Ads - Training Set')
plt.show()

# %% [markdown]
# here, we have taken the points over the main graphs to obtain the predictions.. from the graphs,
# <li>the man with Age 18, No Salary and Age 40, No Salary  most likely donot take the insurance
# <li>the man with Age 40, Salary 100,000 and Age 50, No Salary most likely takes the insurance

# %%
#ORIGINAL ANSWER GIVEN BY RANDOM FOREST 
y_pred1=rf_model.predict(predictions)
y_pred1
# Out:
# array([0, 0, 1, 1], dtype=int64)

# %% [markdown]
# QUESTION 2:

# %%
predictions2=np.array([[18,0],[22,600000],[35,2500000],[60,100000000]])
predictions2=standard.transform(predictions2)
plt.scatter(x_train[:,0], x_train[:,-1], c=y_train)
plt.scatter(predictions2[:,0],predictions2[:,1],color="red",s=80)#in the graph the predicted points are marked with red color
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Social Network Ads - Training Set')
plt.show()
# Out:
# c:\Users\vamsi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# <h5>by this graph,
# <li> the man with Age 18, No Salary will not take insurance but others will</h5>

# %%
#ORIGINAL ANSWER GIVEN BY RANDOM FOREST 
y_pred1=rf_model.predict(predictions2)
y_pred1
# Out:
# array([0, 1, 1, 1], dtype=int64)

# %% [markdown]
# <h2>Hypotheses and Assumptions</h2>
# <h5>
# from this project, we can come to a conclusion that
# <li>18-40 year old people with average or low income most likely willnot take the insurance offered by the company
# <li>people with more than 40 years age and people with high salaries will most likely take insurance offered.
# </h5>

# %% [markdown]
# <h2>Lessons Learned and Real-Life Application</h2>
# <h5>
# <li>Different algorithms have varying strengths and weaknesses.
# <li> this type of machine learning algorithms will help in devoleping a clear idea over the market and target audience.
# <li> Also, it can help in predicting the natural calamities, war targets, etc.
